# %% [markdown]
# # Pandas 2

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# - import urllib.request 是用来进行网络请求的
# - os.path 是用来处理文件路径的
# - zipfile 是用来处理.zip压缩文件的。

# %%
import urllib.request
import os.path
import zipfile

# %%
data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "../data/babynamesbystate.zip"
if not os.path.exists(local_filename): # if the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.sample(5)
# Out:
#        State Sex  Year     Name  Count
# 407807    CA   M  2021    Wylde      6
# 369319    CA   M  2008   Maison     10
# 86206     CA   F  1981   Bertha     77
# 252013    CA   M  1929  Gaylord      7
# 378036    CA   M  2011      Gus     10

# %% [markdown]
# ## query和sort_value按照指定条件查找数据

# %% [markdown]
# 筛选2020年出生的男宝宝的最频繁的名字

# %%
babynames.query('Sex == "M" and Year == 2020').sort_values("Count", ascending = False)
# Out:
#        State Sex  Year        Name  Count
# 402534    CA   M  2020        Noah   2631
# 402535    CA   M  2020        Liam   2431
# 402536    CA   M  2020       Mateo   2080
# 402537    CA   M  2020   Sebastian   1996
# 402538    CA   M  2020      Julian   1688
# ...      ...  ..   ...         ...    ...
# 405091    CA   M  2020       Galen      5
# 405090    CA   M  2020  Fitzgerald      5
# 405089    CA   M  2020    Faustino      5
# 405088    CA   M  2020       Farid      5
# 405330    CA   M  2020       Zymir      5
#
# [2797 rows x 5 columns]

# %%
babynames.query('Sex == "M" and Year == 2020').sort_values("Name")
# Out:
#        State Sex  Year     Name  Count
# 404132    CA   M  2020    Aaden     10
# 404495    CA   M  2020     Aadi      7
# 404496    CA   M  2020  Aaditya      7
# 404976    CA   M  2020    Aalam      5
# 404244    CA   M  2020    Aamir      9
# ...      ...  ..   ...      ...    ...
# 403973    CA   M  2020    Zyair     13
# 403237    CA   M  2020   Zyaire     38
# 404494    CA   M  2020     Zyan      8
# 405330    CA   M  2020    Zymir      5
# 404363    CA   M  2020     Zyon      9
#
# [2797 rows x 5 columns]

# %% [markdown]
# 名字长短排序

# %%
def findLongestName(x):
    return x.str.len()
(
    babynames.query('Sex == "M" and Year == 2020')
             .sort_values("Name", key = lambda x : x.str.len(), ascending = False)
)
# Out:
#        State Sex  Year           Name  Count
# 404620    CA   M  2020  Michaelangelo      7
# 404103    CA   M  2020   Michelangelo     11
# 404102    CA   M  2020   Maximilliano     11
# 402582    CA   M  2020    Christopher    763
# 402636    CA   M  2020    Maximiliano    435
# ...      ...  ..   ...            ...    ...
# 405139    CA   M  2020             Jr      5
# 404542    CA   M  2020             Cj      7
# 404824    CA   M  2020             Jj      6
# 404896    CA   M  2020             Oz      6
# 404962    CA   M  2020             Yi      6
#
# [2797 rows x 5 columns]

# %% [markdown]
# ## 添加新的列

# %%
# 利用str.len()遍历了表格中Name列的数据, 存在name_length这个series中
name_length = babynames["Name"].str.len()

# 创建新列, 值为name_length
babynames["name_lengths"] = name_length

# %% [markdown]
# ## 修改表格为按照指定关键词排序

# %%
babynames = babynames.sort_values(by = "name_lengths", ascending = False)
babynames.head(25)
# Out:
#        State Sex  Year             Name  Count  name_lengths
# 341130    CA   M  1997  Ryanchristopher      5            15
# 348093    CA   M  2000  Franciscojavier      6            15
# 331124    CA   M  1993  Ryanchristopher      5            15
# 337819    CA   M  1996  Franciscojavier      8            15
# 317627    CA   M  1988  Franciscojavier     10            15
# 320534    CA   M  1989  Franciscojavier      6            15
# 343125    CA   M  1998  Franciscojavier      6            15
# 325441    CA   M  1991  Ryanchristopher      7            15
# 340954    CA   M  1997  Franciscojavier      5            15
# 325562    CA   M  1991  Franciscojavier      6            15
# 316193    CA   M  1987  Franciscojavier      5            15
# 331009    CA   M  1993  Johnchristopher      5            15
# 102512    CA   F  1986  Mariadelosangel      5            15
# 338140    CA   M  1996   Christianjames      6            14
# 71333     CA   F  1974   Mariadelourdes      5            14
# 73542     CA   F  1975   Mariadelcarmen      5            14
# 121864    CA   F  1992   Mariaguadalupe     13            14
# 340235    CA   M  1997   Michaelanthony      9            14
# 335598    CA   M  1995   Michaelanthony      7            14
# 96434     CA   F  1984   Christinamarie      5            14
# 139515    CA   F  1997   Mariaguadalupe     24            14
# 140207    CA   F  1997   Mariadelcarmen     12            14
# 101855    CA   F  1986   Mariadelcarmen      7            14
# 337551    CA   M  1996   Michaelanthony     11            14
# 158782    CA   F  2002   Mariaguadalupe     10            14

# %% [markdown]
# ## 删除某一列, 要指定axis为row还是column

# %%
babynames = babynames.drop("name_lengths", axis = "columns")
babynames.head(5)
# Out:
#        State Sex  Year             Name  Count
# 341130    CA   M  1997  Ryanchristopher      5
# 348093    CA   M  2000  Franciscojavier      6
# 331124    CA   M  1993  Ryanchristopher      5
# 337819    CA   M  1996  Franciscojavier      8
# 317627    CA   M  1988  Franciscojavier     10

# %% [markdown]
#  ## 想要统计出name中含有dr和ea的次数, 并创建新的列

# %%
def dr_ea_count(string):
    return string.count('dr') + string.count('ea')

babynames["dr_ea_count"] = babynames["Name"].map(dr_ea_count)
babynames = babynames.sort_values(by = "dr_ea_count", ascending = False)
babynames.head(5)
# Out:
#        State Sex  Year      Name  Count  dr_ea_count
# 108738    CA   F  1988  Deandrea      5            3
# 131037    CA   F  1994  Leandrea      5            3
# 115965    CA   F  1990  Deandrea      5            3
# 101982    CA   F  1986  Deandrea      6            3
# 311780    CA   M  1985  Deandrea      6            3

# %% [markdown]
# ## 哪个女性名字的下降率最高 Female Name whose popularity has dropped the most.

# %%
max_name = max(babynames.query("Name == 'Jennifer' and Sex == 'F'")["Count"])
max_name
# Out:
# 6065

# %%
current_name = babynames.query("Name == 'Jennifer' and Sex == 'F'")["Count"].iloc[-1]
current_name
# Out:
# 88

# %%
current_name / max_name
# Out:
# 0.014509480626545754

# %%
def ratio_to_peak(series):
    peak = max(series)
    current = series.iloc[-1]
    return current / peak

# %%
series1 = babynames.query("Name == 'Eva' and Sex == 'F'")["Count"]
ratio_to_peak(series1)
# Out:
# 0.5335628227194492

# %%
series1
# Out:
# 54         29
# 294        29
# 540        42
# 830        71
# 1177       56
#          ...
# 224975    466
# 228648    378
# 232263    396
# 235946    343
# 239661    310
# Name: Count, Length: 114, dtype: int64

# %% [markdown]
# ## 当你想要用上面的方法遍历所有名字找出ratio最低的名字
# ### Approach 1: loop
# 但这不是个好方法, 我们要避免慢速的loop

# %%
female_babynames = babynames.query("Sex == 'F'").loc[:,["Name","Count","Year"]] 
female_babynames
# Out:
#             Name  Count  Year
# 0           Mary    295  1910
# 1          Helen    239  1910
# 2        Dorothy    220  1910
# 3       Margaret    163  1910
# 4        Frances    134  1910
# ...          ...    ...   ...
# 243185  Zeppelin      5  2023
# 243186   Zhamira      5  2023
# 243187      Zina      5  2023
# 243188     Zooey      5  2023
# 243189     Zosia      5  2023
#
# [243190 rows x 3 columns]

# %%
rtps = {}
for name in female_babynames["Name"].unique()[0:10]:
    counts_of_current_name = female_babynames[female_babynames["Name"] == name]["Count"]
    rtps[name] = ratio_to_peak(counts_of_current_name)

rtps = pd.Series(rtps)
rtps
# Out:
# Deandrea      1.000000
# Leandrea      1.000000
# Andrea        0.737674
# Alexandrea    0.716216
# Audrea        0.857143
# Deandra       0.206897
# Leandra       0.275000
# Adreana       0.750000
# Andreah       1.000000
# Adreanna      1.000000
# dtype: float64

# %%
rtps.sort_values()
# Out:
# Deandra       0.206897
# Leandra       0.275000
# Alexandrea    0.716216
# Andrea        0.737674
# Adreana       0.750000
# Audrea        0.857143
# Deandrea      1.000000
# Leandrea      1.000000
# Andreah       1.000000
# Adreanna      1.000000
# dtype: float64

# %% [markdown]
# ### Approach 2: Groupby and Agg
# - groupby 是一个非常强大的功能，它允许你根据一个或多个键（列）对数据进行分组，并应用聚合函数或转换函数。
# - agg 方法是 DataFrameGroupBy 对象的一个功能，它允许你对分组后的数据应用一个或多个聚合函数。

# %% [markdown]
# ![groupby and egg](img/groupby.png)

# %%
female_babynames.groupby("Name").agg(ratio_to_peak)
# Out:
#             Count  Year
# Name
# Aadhini  1.000000   1.0
# Aadhira  0.500000   1.0
# Aadhya   0.760000   1.0
# Aadya    0.758621   1.0
# Aahana   0.269231   1.0
# ...           ...   ...
# Zyanya   0.800000   1.0
# Zyla     1.000000   1.0
# Zylah    1.000000   1.0
# Zyra     1.000000   1.0
# Zyrah    0.833333   1.0
#
# [13930 rows x 2 columns]

# %% [markdown]
# - 之所以year都是1, 因为函数默认是找出最大值和最后一个值, 再进行相除
# - 按照年份的话, 两者肯定都是相同的, 因此结果为1
# - 如果还有其他的列, 比如都是无法进行函数内的运算时, 就不会显示那个列
# - 通过下面的显示你可以更好的理解

# %%
female_babynames.query('Name == "Aahana"')
# Out:
#           Name  Count  Year
# 179971  Aahana      6  2007
# 184205  Aahana      6  2008
# 188119  Aahana      7  2009
# 191409  Aahana     12  2010
# 196324  Aahana      7  2011
# 199101  Aahana     17  2012
# 203956  Aahana      9  2013
# 207655  Aahana     11  2014
# 216042  Aahana      8  2016
# 219553  Aahana     10  2017
# 222293  Aahana     26  2018
# 226993  Aahana     10  2019
# 235373  Aahana      5  2021
# 238450  Aahana      7  2022

# %% [markdown]
# - 指定具体想要哪一列, 双重括号[["Count"]]则是告诉Pandas我们想要选取的是一个多级索引中的列

# %%
rtp_table = female_babynames.groupby("Name")[["Count"]].agg(ratio_to_peak)
rtp_table
# Out:
#             Count
# Name
# Aadhini  1.000000
# Aadhira  0.500000
# Aadhya   0.760000
# Aadya    0.758621
# Aahana   0.269231
# ...           ...
# Zyanya   0.800000
# Zyla     1.000000
# Zylah    1.000000
# Zyra     1.000000
# Zyrah    0.833333
#
# [13930 rows x 1 columns]

# %% [markdown]
# #### 更改列名

# %%
rtp_table = rtp_table.rename(columns = {"Count":"Count RTP"})
rtp_table
# Out:
#          Count RTP
# Name
# Aadhini   1.000000
# Aadhira   0.500000
# Aadhya    0.760000
# Aadya     0.758621
# Aahana    0.269231
# ...            ...
# Zyanya    0.800000
# Zyla      1.000000
# Zylah     1.000000
# Zyra      1.000000
# Zyrah     0.833333
#
# [13930 rows x 1 columns]

# %%
rtp_table.sort_values("Count RTP")
# Out:
#          Count RTP
# Name
# Debra     0.001512
# Debbie    0.002815
# Tammy     0.003249
# Pamela    0.003602
# Cheryl    0.003819
# ...            ...
# Kanwal    1.000000
# Kansas    1.000000
# Kanon     1.000000
# Karessa   1.000000
# Kaylany   1.000000
#
# [13930 rows x 1 columns]

# %% [markdown]
# ## Groupby Puzzles

# %% [markdown]
# 即使你当前使用的Pandas版本允许你传递函数本身，为了代码的健壮性和未来兼容性，使用字符串形式指定聚合函数是一个好习惯。

# %% [markdown]
# ### 如果我想要计算这些名字count的总和

# %%
puzzle1 = female_babynames.groupby("Name")[["Count"]].agg('sum')
puzzle1
# Out:
#          Count
# Name
# Aadhini      6
# Aadhira     34
# Aadhya     468
# Aadya      290
# Aahana     141
# ...        ...
# Zyanya     206
# Zyla       179
# Zylah      143
# Zyra       131
# Zyrah       21
#
# [13930 rows x 1 columns]

# %% [markdown]
# ### 如果我想要计算每年出生婴儿的总和

# %%
female_babynames.groupby("Year")[["Count"]].agg('sum')
# Out:
#        Count
# Year
# 1910    5950
# 1911    6602
# 1912    9804
# 1913   11860
# 1914   13815
# ...      ...
# 2019  184384
# 2020  173966
# 2021  174190
# 2022  173353
# 2023  163845
#
# [114 rows x 1 columns]

# %% [markdown]
# 使用groupby之后直接.sum()使用函数也可以

# %%
puzzle2 = female_babynames.groupby("Year")[["Count"]].sum()
puzzle2
# Out:
#        Count
# Year
# 1910    5950
# 1911    6602
# 1912    9804
# 1913   11860
# 1914   13815
# ...      ...
# 2019  184384
# 2020  173966
# 2021  174190
# 2022  173353
# 2023  163845
#
# [114 rows x 1 columns]

# %% [markdown]
# ### 我想按党派筛选出选票最多的总统

# %% [markdown]
# 下面这样做的话, 只有选票是最多的, 但是year, candidate, result都和选票最多的那个候选人的信息对应不上

# %%
elections = pd.read_csv("../data/elections.csv")
table = elections.groupby("Party").agg('max')
table
# Out:
#                        Year              Candidate  Popular vote Result  \
# Party
# American               1976     Thomas J. Anderson        873053   loss
# American Independent   1976          Lester Maddox       9901118   loss
# Anti-Masonic           1832           William Wirt        100715   loss
# Anti-Monopoly          1884        Benjamin Butler        134294   loss
# Citizens               1980         Barry Commoner        233052   loss
# Communist              1932      William Z. Foster        103307   loss
# Constitution           2016       Michael Peroutka        203091   loss
# Constitutional Union   1860              John Bell        590901   loss
# Democratic             2020         Woodrow Wilson      81268924    win
# Democratic-Republican  1824      John Quincy Adams        151271    win
# Dixiecrat              1948         Strom Thurmond       1175930   loss
# Farmer–Labor           1920  Parley P. Christensen        265398   loss
# Free Soil              1852       Martin Van Buren        291501   loss
# Green                  2020            Ralph Nader       2882955   loss
# Greenback              1880        James B. Weaver        308649   loss
# Independent            2016             Ross Perot      19743821   loss
# Liberal Republican     1872         Horace Greeley       2834761   loss
# Libertarian            2020               Ron Paul       4489235   loss
# National Democratic    1896         John M. Palmer        134645   loss
# National Republican    1832      John Quincy Adams        500897   loss
# National Union         1864        Abraham Lincoln       2211317    win
# Natural Law            1996           John Hagelin        113670   loss
# New Alliance           1988          Lenora Fulani        217221   loss
# Northern Democratic    1860     Stephen A. Douglas       1380202   loss
# Populist               1992       Thomas E. Watson       1041028   loss
# Progressive            1952       Vincent Hallinan       4831706   loss
# Prohibition            1948       Silas C. Swallow        270879   loss
# Reform                 2000             Ross Perot       8085294   loss
# Republican             2020           William Taft      74216154    win
# Socialist              1948          Norman Thomas        913693   loss
# Southern Democratic    1860   John C. Breckinridge        848019   loss
# States' Rights         1956     T. Coleman Andrews        107929   loss
# Taxpayers              1996        Howard Phillips        184656   loss
# Union                  1936          William Lemke        892378   loss
# Union Labor            1888         Alson Streeter        146602   loss
# Whig                   1852         Zachary Taylor       1386942    win
#
#                                %
# Party
# American               21.554001
# American Independent   13.571218
# Anti-Masonic            7.821583
# Anti-Monopoly           1.335838
# Citizens                0.270182
# Communist               0.261069
# Constitution            0.152398
# Constitutional Union   12.639283
# Democratic             61.344703
# Democratic-Republican  57.210122
# Dixiecrat               2.412304
# Farmer–Labor            0.995804
# Free Soil              10.138474
# Green                   2.741176
# Greenback               3.352344
# Independent            18.956298
# Liberal Republican     44.071406
# Libertarian             3.307714
# National Democratic     0.969566
# National Republican    43.796073
# National Union         54.951512
# Natural Law             0.118219
# New Alliance            0.237804
# Northern Democratic    29.522311
# Populist                8.645038
# Progressive            27.457433
# Prohibition             2.249468
# Reform                  8.408844
# Republican             60.907806
# Socialist               6.004354
# Southern Democratic    18.138998
# States' Rights          0.174883
# Taxpayers               0.192045
# Union                   1.960733
# Union Labor             1.288861
# Whig                   53.051213

# %% [markdown]
# 更好的方法:

# %%
table2 = elections.sort_values("%", ascending = False)
table2.head(10)
# Out:
#      Year           Candidate                  Party  Popular vote Result  \
# 114  1964      Lyndon Johnson             Democratic      43127041    win
# 91   1936  Franklin Roosevelt             Democratic      27752648    win
# 120  1972       Richard Nixon             Republican      47168710    win
# 79   1920      Warren Harding             Republican      16144093    win
# 133  1984       Ronald Reagan             Republican      54455472    win
# 84   1928      Herbert Hoover             Republican      21427123    win
# 86   1932  Franklin Roosevelt             Democratic      22821277    win
# 109  1956   Dwight Eisenhower             Republican      35579180    win
# 0    1824      Andrew Jackson  Democratic-Republican        151271   loss
# 60   1904  Theodore Roosevelt             Republican       7630557    win
#
#              %
# 114  61.344703
# 91   60.978107
# 120  60.907806
# 79   60.574501
# 133  59.023326
# 84   58.368524
# 86   57.672125
# 109  57.650654
# 0    57.210122
# 60   56.562787

# %% [markdown]
# 有非常多种方法可以实现目标

# %%
table_result = table2.groupby("Party").agg(lambda x:x.iloc[0])
# table_result = table2.groupby("Party").first() 也可以
# table_result = table2.drop_duplicates(["Party"]) 也可以
table_result
# Out:
#                        Year               Candidate  Popular vote Result  \
# Party
# American               1856        Millard Fillmore        873053   loss
# American Independent   1968          George Wallace       9901118   loss
# Anti-Masonic           1832            William Wirt        100715   loss
# Anti-Monopoly          1884         Benjamin Butler        134294   loss
# Citizens               1980          Barry Commoner        233052   loss
# Communist              1932       William Z. Foster        103307   loss
# Constitution           2008           Chuck Baldwin        199750   loss
# Constitutional Union   1860               John Bell        590901   loss
# Democratic             1964          Lyndon Johnson      43127041    win
# Democratic-Republican  1824          Andrew Jackson        151271   loss
# Dixiecrat              1948          Strom Thurmond       1175930   loss
# Farmer–Labor           1920   Parley P. Christensen        265398   loss
# Free Soil              1848        Martin Van Buren        291501   loss
# Green                  2000             Ralph Nader       2882955   loss
# Greenback              1880         James B. Weaver        308649   loss
# Independent            1992              Ross Perot      19743821   loss
# Liberal Republican     1872          Horace Greeley       2834761   loss
# Libertarian            2016            Gary Johnson       4489235   loss
# National Democratic    1896          John M. Palmer        134645   loss
# National Republican    1828       John Quincy Adams        500897   loss
# National Union         1864         Abraham Lincoln       2211317    win
# Natural Law            1996            John Hagelin        113670   loss
# New Alliance           1988           Lenora Fulani        217221   loss
# Northern Democratic    1860      Stephen A. Douglas       1380202   loss
# Populist               1892         James B. Weaver       1041028   loss
# Progressive            1912      Theodore Roosevelt       4122721   loss
# Prohibition            1892            John Bidwell        270879   loss
# Reform                 1996              Ross Perot       8085294   loss
# Republican             1972           Richard Nixon      47168710    win
# Socialist              1912          Eugene V. Debs        901551   loss
# Southern Democratic    1860    John C. Breckinridge        848019   loss
# States' Rights         1956      T. Coleman Andrews        107929   loss
# Taxpayers              1996         Howard Phillips        184656   loss
# Union                  1936           William Lemke        892378   loss
# Union Labor            1888          Alson Streeter        146602   loss
# Whig                   1840  William Henry Harrison       1275583    win
#
#                                %
# Party
# American               21.554001
# American Independent   13.571218
# Anti-Masonic            7.821583
# Anti-Monopoly           1.335838
# Citizens                0.270182
# Communist               0.261069
# Constitution            0.152398
# Constitutional Union   12.639283
# Democratic             61.344703
# Democratic-Republican  57.210122
# Dixiecrat               2.412304
# Farmer–Labor            0.995804
# Free Soil              10.138474
# Green                   2.741176
# Greenback               3.352344
# Independent            18.956298
# Liberal Republican     44.071406
# Libertarian             3.307714
# National Democratic     0.969566
# National Republican    43.796073
# National Union         54.951512
# Natural Law             0.118219
# New Alliance            0.237804
# Northern Democratic    29.522311
# Populist                8.645038
# Progressive            27.457433
# Prohibition             2.249468
# Reform                  8.408844
# Republican             60.907806
# Socialist               6.004354
# Southern Democratic    18.138998
# States' Rights          0.174883
# Taxpayers               0.192045
# Union                   1.960733
# Union Labor             1.288861
# Whig                   53.051213

# %%
table2.drop_duplicates(["Party"])

# %% [markdown]
# ### groupby.size()

# %%
elections.groupby("Party").size().sort_values(ascending = False).head(5)
# Out:
# Party
# Democratic     47
# Republican     41
# Libertarian    12
# Prohibition    11
# Socialist      10
# dtype: int64

# %% [markdown]
# ### groupby.filter()

# %%
elections.groupby("Year").filter(lambda sf:sf["%"].max() < 45)
# Out:
#      Year             Candidate                 Party  Popular vote Result  \
# 23   1860       Abraham Lincoln            Republican       1855993    win
# 24   1860             John Bell  Constitutional Union        590901   loss
# 25   1860  John C. Breckinridge   Southern Democratic        848019   loss
# 26   1860    Stephen A. Douglas   Northern Democratic       1380202   loss
# 66   1912        Eugene V. Debs             Socialist        901551   loss
# 67   1912      Eugene W. Chafin           Prohibition        208156   loss
# 68   1912    Theodore Roosevelt           Progressive       4122721   loss
# 69   1912          William Taft            Republican       3486242   loss
# 70   1912        Woodrow Wilson            Democratic       6296284    win
# 115  1968        George Wallace  American Independent       9901118   loss
# 116  1968       Hubert Humphrey            Democratic      31271839   loss
# 117  1968         Richard Nixon            Republican      31783783    win
# 139  1992          Andre Marrou           Libertarian        290087   loss
# 140  1992          Bill Clinton            Democratic      44909806    win
# 141  1992              Bo Gritz              Populist        106152   loss
# 142  1992     George H. W. Bush            Republican      39104550   loss
# 143  1992            Ross Perot           Independent      19743821   loss
#
#              %
# 23   39.699408
# 24   12.639283
# 25   18.138998
# 26   29.522311
# 66    6.004354
# 67    1.386325
# 68   27.457433
# 69   23.218466
# 70   41.933422
# 115  13.571218
# 116  42.863537
# 117  43.565246
# 139   0.278516
# 140  43.118485
# 141   0.101918
# 142  37.544784
# 143  18.956298

# %% [markdown]
# ### 算出每一年出生的男孩女孩分别的总数

# %%
print(babynames.dtypes)
# Out:
# State    object
# Sex      object
# Year      int64
# Name     object
# Count     int64
# dtype: object

# %%
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    NaN
# 1         CA   F  1910     Helen    NaN
# 2         CA   F  1910   Dorothy    NaN
# 3         CA   F  1910  Margaret    NaN
# 4         CA   F  1910   Frances    NaN
# ...      ...  ..   ...       ...    ...
# 413889    CA   M  2023      Ziah    NaN
# 413890    CA   M  2023    Ziaire    NaN
# 413891    CA   M  2023    Zidane    NaN
# 413892    CA   M  2023      Zyan    NaN
# 413893    CA   M  2023      Zyir    NaN
#
# [413894 rows x 5 columns]

# %% [markdown]
# #### group a DataFrame by specified feature with specified columns

# %%
babynames.groupby("Year")["Count"].sum()
# Out:
# Year
# 1910      9163
# 1911      9983
# 1912     17946
# 1913     22094
# 1914     26926
#          ...
# 2019    387325
# 2020    363307
# 2021    363206
# 2022    361960
# 2023    342550
# Name: Count, Length: 114, dtype: int64

# %% [markdown]
# #### group a DataFrame by multiple features with specified columns

# %%
babynames.groupby(["Year","Sex"])["Count"].agg('sum').head(6)
# Out:
# Year  Sex
# 1910  F      5950
#       M      3213
# 1911  F      6602
#       M      3381
# 1912  F      9804
#       M      8142
# Name: Count, dtype: int64

# %%
babynames.groupby(["Sex","Year"])["Count"].agg('sum').head(6)
# Out:
# Sex  Year
# F    1910     5950
#      1911     6602
#      1912     9804
#      1913    11860
#      1914    13815
#      1915    18643
# Name: Count, dtype: int64

# %% [markdown]
# ## 汇总表 pivot tables

# %%
babynames_pivot = babynames.pivot_table(
    index = "Year",
    columns = "Sex",
    values = ['Count'],
    aggfunc = 'sum',
)
babynames_pivot
# Out:
#        Count
# Sex        F       M
# Year
# 1910    5950    3213
# 1911    6602    3381
# 1912    9804    8142
# 1913   11860   10234
# 1914   13815   13111
# ...      ...     ...
# 2019  184384  202941
# 2020  173966  189341
# 2021  174190  189016
# 2022  173353  188607
# 2023  163845  178705
#
# [114 rows x 2 columns]

# %% [markdown]
# ## 合并表格

# %%
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# 4    54.574789
# ..         ...
# 177   1.073699
# 178  51.311515
# 179  46.858542
# 180   1.177979
# 181   0.255731
#
# [182 rows x 6 columns]

# %%
male_2020_babynames = babynames.query('Sex == "M" and Year == 2020')
male_2020_babynames
# Out:
#        State Sex  Year       Name  Count
# 402534    CA   M  2020       Noah   2631
# 402535    CA   M  2020       Liam   2431
# 402536    CA   M  2020      Mateo   2080
# 402537    CA   M  2020  Sebastian   1996
# 402538    CA   M  2020     Julian   1688
# ...      ...  ..   ...        ...    ...
# 405326    CA   M  2020       Zevi      5
# 405327    CA   M  2020      Ziaan      5
# 405328    CA   M  2020       Ziad      5
# 405329    CA   M  2020     Ziaire      5
# 405330    CA   M  2020      Zymir      5
#
# [2797 rows x 5 columns]

# %%
elections["First Name"] = elections["Candidate"].str.split().str[0]
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              % First Name
# 0    57.210122     Andrew
# 1    42.789878       John
# 2    56.203927     Andrew
# 3    43.796073       John
# 4    54.574789     Andrew
# ..         ...        ...
# 177   1.073699       Jill
# 178  51.311515     Joseph
# 179  46.858542     Donald
# 180   1.177979         Jo
# 181   0.255731     Howard
#
# [182 rows x 7 columns]

# %% [markdown]
#  merge 函数会根据 left_on 和 right_on 指定的列中的值，在两个 DataFrame 中查找匹配项。只有当两个 DataFrame 中的键值相匹配时，相应的行才会在结果 DataFrame 中一起出现。

# %%
merged = pd.merge(left = elections, right = male_2020_babynames,
                 left_on = "First Name", right_on = "Name")
merged
# Out:
#      Year_x          Candidate                  Party  Popular vote Result  \
# 0      1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1      1824  John Quincy Adams  Democratic-Republican        113142    win
# 2      1828     Andrew Jackson             Democratic        642806    win
# 3      1828  John Quincy Adams    National Republican        500897   loss
# 4      1832     Andrew Jackson             Democratic        702735    win
# ..      ...                ...                    ...           ...    ...
# 142    2016      Evan McMullin            Independent        732273   loss
# 143    2016       Gary Johnson            Libertarian       4489235   loss
# 144    2020       Joseph Biden             Democratic      81268924    win
# 145    2020       Donald Trump             Republican      74216154   loss
# 146    2020     Howard Hawkins                  Green        405035   loss
#
#              % First Name State Sex  Year_y    Name  Count
# 0    57.210122     Andrew    CA   M    2020  Andrew    875
# 1    42.789878       John    CA   M    2020    John    623
# 2    56.203927     Andrew    CA   M    2020  Andrew    875
# 3    43.796073       John    CA   M    2020    John    623
# 4    54.574789     Andrew    CA   M    2020  Andrew    875
# ..         ...        ...   ...  ..     ...     ...    ...
# 142   0.539546       Evan    CA   M    2020    Evan    598
# 143   3.307714       Gary    CA   M    2020    Gary     22
# 144  51.311515     Joseph    CA   M    2020  Joseph   1003
# 145  46.858542     Donald    CA   M    2020  Donald     40
# 146   0.255731     Howard    CA   M    2020  Howard     14
#
# [147 rows x 12 columns]

# %%
merged.sort_values("Count")
# Out:
#      Year_x          Candidate          Party  Popular vote Result          %  \
# 127    1996         Ross Perot         Reform       8085294   loss   8.408844
# 122    1996       Bill Clinton     Democratic      47400125    win  49.296938
# 121    1992         Ross Perot    Independent      19743821   loss  18.956298
# 118    1992       Bill Clinton     Democratic      44909806    win  43.118485
# 96     1968    Hubert Humphrey     Democratic      31271839   loss  42.863537
# ..      ...                ...            ...           ...    ...        ...
# 111    1984     David Bergland    Libertarian        228111   loss   0.247245
# 131    2004         David Cobb          Green        119859   loss   0.098088
# 32     1884    Benjamin Butler  Anti-Monopoly        134294   loss   1.335838
# 35     1888  Benjamin Harrison     Republican       5443633    win  47.858041
# 37     1892  Benjamin Harrison     Republican       5176108   loss  42.984101
#
#     First Name State Sex  Year_y      Name  Count
# 127       Ross    CA   M    2020      Ross      5
# 122       Bill    CA   M    2020      Bill      5
# 121       Ross    CA   M    2020      Ross      5
# 118       Bill    CA   M    2020      Bill      5
# 96      Hubert    CA   M    2020    Hubert      5
# ..         ...   ...  ..     ...       ...    ...
# 111      David    CA   M    2020     David   1165
# 131      David    CA   M    2020     David   1165
# 32    Benjamin    CA   M    2020  Benjamin   1654
# 35    Benjamin    CA   M    2020  Benjamin   1654
# 37    Benjamin    CA   M    2020  Benjamin   1654
#
# [147 rows x 12 columns]

# %%
# Out:
# 0        151271
# 1        113142
# 2        642806
# 3        500897
# 4        702735
#          ...
# 177     1457226
# 178    81268924
# 179    74216154
# 180     1865724
# 181      405035
# Name: Popular vote, Length: 182, dtype: int64
