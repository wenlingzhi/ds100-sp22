# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6]
y = [7,1,5,3,6,4]
plt.plot(x,y)

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]
plt.plot(x,y)

# %%
y = [1,4,3,6,5,7,3]
x = [1,2,3,4,5,6,7]
plt.plot(x,y)

# %%
import re

# %%
text = "I have 10 apples, GREAT!"
pattern = r"[a-z0-9]+"
result = re.findall(pattern,text)
result
# Out:
# ['have', '10', 'apples']

# %%
text = "I've got 10 eggs, 20 gooses, and 30 giants."
pattern = r"[0-9]{2} [a-z]+"
result = re.findall(pattern,text)
result
# Out:
# ['10 eggs', '20 gooses', '30 giants']

# %%
text = "abc, 123"
pattern = r"[a-z1,9]+"
result = re.findall(pattern,text)
result
# Out:
# ['abc,', '1']

# %%
log = r'169.237.46.168 - - [26/Jan/2014:10:47:58-0800]"GET /stat141/Winter04/ HTTP/1.1" 200 2585"http://anson.ucdavis.edu/courses/"'
pattern = r"\[(.+)\/(.+)\/([^:]+).*\]"
matches = re.findall(pattern,log)
day,month,year = matches[0]
# Out:
# [('26', 'Jan', '2014')]

# %%
sometext = "a big moon, between us..."
pattern = r"[^aoeiu]+"
re.sub(pattern,".",sometext)
# Out:
# 'a.i.oo.e.ee.u.'
